# %% [markdown]
# # Car price predictor model
#
# Rusty Bargain, a secondhand car marketplace, is developing an app. The app needs an algorithm to predict car prices based on the vehicle's specifications.
#
# Rust Bargain is interested in
# - prediction quality,
# - prediction speed, and
# - the time required to train the model.

# %% [markdown]
# # Loading libraries

# %%
# For numerical operations
import numpy as np

# For dataframe manipulation
import pandas as pd

# Scikit-Learn
## Tools
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split

## Models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Gradient-boosting models
## XGBoost
from xgboost import XGBRegressor
## LightGBM
from lightgbm import LGBMRegressor
## CatBoost
from catboost import CatBoostRegressor

import time

# Setting the global random_state value for this project
random_state = 12345

# Checking if all libraries were loaded properly
print('Loading completed successfully.')
# Out:
# Loading completed successfully.

# %% [markdown]
# # Loading dataset
#
# The data has 16 columns:
# - `DateCrawled` - profile download date
# - `VehicleType`
# - `RegistrationYear`
# - `Gearbox`
# - `Power` - in HP
# - `Model`
# - `Mileage` - in kilometers
# - `RegistrationMonth`
# - `FuelType`
# - `Brand`
# - `NotRepaired` - whether or not the vehicle has been repaired before
# - `DateCreated` - profile creation date
# - `NumberOfPictures` - number of pictures of the vehicle
# - `PostalCode` - owner's postal code
# - `LastSeen` - last time the owner was active
# - `Price` - vehicle price in euros, our target.

# %%
# If run on the platform
try:
    df = pd.read_csv('\datasets\car_data.csv')

# If run locally
except:
    df = pd.read_csv('datasets/car_data.csv')

# %%
# Getting random samples of the data
df.sample(5, random_state=random_state)
# Out:
#              DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 18734   04/04/2016 13:36  16900         bus              2010    auto    150
# 141787  07/03/2016 17:57  15500       other              2011  manual    143
# 37523   24/03/2016 09:37   3600       sedan              2004  manual    125
# 194192  15/03/2016 09:49   8990       sedan              2007    auto    224
# 110210  29/03/2016 23:43   2500       other              1994  manual     68
#
#               Model  Mileage  RegistrationMonth  FuelType          Brand  \
# 18734         viano   150000                  4  gasoline  mercedes_benz
# 141787          1er    40000                  5  gasoline            bmw
# 37523         astra   150000                 12    petrol           opel
# 194192     c_klasse   150000                  9  gasoline  mercedes_benz
# 110210  transporter   150000                  9  gasoline     volkswagen
#
#        NotRepaired       DateCreated  NumberOfPictures  PostalCode  \
# 18734           no  04/04/2016 00:00                 0       60326
# 141787          no  07/03/2016 00:00                 0       35083
# 37523           no  24/03/2016 00:00                 0       13627
# 194192          no  15/03/2016 00:00                 0       58135
# 110210          no  29/03/2016 00:00                 0       24598
#
#                 LastSeen
# 18734   05/04/2016 12:18
# 141787  06/04/2016 20:19
# 37523   24/03/2016 10:38
# 194192  18/03/2016 02:17
# 110210  02/04/2016 12:45

# %%
# Getting general information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %%
# Checking for missing values
df.isna().sum()
# Out:
# DateCrawled              0
# Price                    0
# VehicleType          37490
# RegistrationYear         0
# Gearbox              19833
# Power                    0
# Model                19705
# Mileage                  0
# RegistrationMonth        0
# FuelType             32895
# Brand                    0
# NotRepaired          71154
# DateCreated              0
# NumberOfPictures         0
# PostalCode               0
# LastSeen                 0
# dtype: int64

# %%
# Checking for duplicates
df.duplicated().sum()
# Out:
# 262

# %%
# Checking statistical description
df.describe()
# Out:
#                Price  RegistrationYear          Power        Mileage  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %% [markdown]
# Findings:
# - The set comprises of 354,369 rows across 16 columns.
# - Some of the columns have missing values of varying amounts.
# - Some of the rows are duplicates.
# - Some of the columns have impossible values, e.g.:
#     - `0` in `Price`, `Power`, and `RegistrationMonth`,
#     - Impossible years in `RegistrationYear`.
# - Some features won't have any significance in price predictions.
# - The set has many categorical features, which need to be encoded before processing by ML algorithms.

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Dropping duplicates
#
# The set has 262 duplicates. We will drop these rows.

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (354107, 16)

# %% [markdown]
# ## Treating missing values

# %%
df[df.isna().any(axis=1)].shape
# Out:
# (108540, 16)

# %%
df.isna().sum()
# Out:
# DateCrawled              0
# Price                    0
# VehicleType          37484
# RegistrationYear         0
# Gearbox              19830
# Power                    0
# Model                19701
# Mileage                  0
# RegistrationMonth        0
# FuelType             32889
# Brand                    0
# NotRepaired          71145
# DateCreated              0
# NumberOfPictures         0
# PostalCode               0
# LastSeen                 0
# dtype: int64

# %% [markdown]
# All of the missing values are found in categorical features. We can guess `VehicleType`s based on its `Model`. However, other features cannot be easily inferred because the same model can have different specifications. Thus, we will fill these (and `VehicleType`s of unknown `Model`) with a placeholder categorical value of `unknown`.

# %%
# Creating a dictionary to map VehicleType-Model values
## Getting only unique values
df_unique = df[(df['VehicleType'].isna() == False) & (df['Model'].isna() == False)][['VehicleType', 'Model']].copy()
df_unique.drop_duplicates(subset='Model', keep='first', inplace=True)
df_unique = df_unique[['Model', 'VehicleType']]

## Converting value pairs into a dict
model_type_dict = dict(df_unique.values)
model_type_dict
# Out:
# {'grand': 'suv',
#  'golf': 'small',
#  'fabia': 'small',
#  '3er': 'sedan',
#  '2_reihe': 'convertible',
#  'other': 'sedan',
#  'c_max': 'bus',
#  '3_reihe': 'sedan',
#  'passat': 'wagon',
#  'navara': 'suv',
#  'ka': 'small',
#  'twingo': 'small',
#  'a_klasse': 'bus',
#  'scirocco': 'coupe',
#  '5er': 'sedan',
#  'arosa': 'small',
#  'civic': 'sedan',
#  'transporter': 'bus',
#  'punto': 'small',
#  'e_klasse': 'sedan',
#  'kadett': 'other',
#  'one': 'sedan',
#  'fortwo': 'small',
#  'clio': 'small',
#  '1er': 'sedan',
#  'b_klasse': 'bus',
#  'signum': 'wagon',
#  'astra': 'wagon',
#  'a8': 'sedan',
#  'jetta': 'sedan',
#  'polo': 'small',
#  'fiesta': 'small',
#  'c_klasse': 'wagon',
#  'micra': 'small',
#  'vito': 'other',
#  'sprinter': 'bus',
#  '156': 'wagon',
#  'escort': 'sedan',
#  'forester': 'wagon',
#  'xc_reihe': 'suv',
#  'scenic': 'bus',
#  'a4': 'sedan',
#  'a1': 'small',
#  'combo': 'bus',
#  'focus': 'wagon',
#  'tt': 'coupe',
#  'corsa': 'small',
#  'a6': 'wagon',
#  'jazz': 'small',
#  'omega': 'sedan',
#  'slk': 'sedan',
#  '7er': 'sedan',
#  '80': 'convertible',
#  '147': 'sedan',
#  'meriva': 'bus',
#  'z_reihe': 'convertible',
#  'sorento': 'suv',
#  'v40': 'wagon',
#  'ibiza': 'small',
#  'mustang': 'convertible',
#  'eos': 'convertible',
#  'touran': 'bus',
#  'getz': 'small',
#  'insignia': 'wagon',
#  'a3': 'wagon',
#  'megane': 'convertible',
#  'lupo': 'small',
#  'r19': 'sedan',
#  'mondeo': 'wagon',
#  'cordoba': 'wagon',
#  'colt': 'sedan',
#  'impreza': 'sedan',
#  'vectra': 'sedan',
#  'berlingo': 'bus',
#  'tiguan': 'suv',
#  'sharan': 'bus',
#  '6_reihe': 'sedan',
#  'c4': 'coupe',
#  'panda': 'small',
#  'up': 'small',
#  'i_reihe': 'wagon',
#  'ceed': 'sedan',
#  'kangoo': 'bus',
#  '5_reihe': 'bus',
#  'yeti': 'suv',
#  'octavia': 'wagon',
#  'zafira': 'bus',
#  'mii': 'small',
#  'rx_reihe': 'coupe',
#  '6er': 'coupe',
#  'fox': 'small',
#  'matiz': 'small',
#  'beetle': 'small',
#  'rio': 'small',
#  'touareg': 'suv',
#  'logan': 'wagon',
#  'caddy': 'wagon',
#  'spider': 'convertible',
#  'cuore': 'small',
#  's_max': 'bus',
#  'modus': 'bus',
#  'a2': 'small',
#  'galaxy': 'bus',
#  'c3': 'small',
#  'viano': 'bus',
#  's_klasse': 'sedan',
#  '1_reihe': 'small',
#  'avensis': 'wagon',
#  'roomster': 'bus',
#  'sl': 'convertible',
#  'kaefer': 'convertible',
#  'santa': 'suv',
#  'cooper': 'small',
#  'leon': 'sedan',
#  '4_reihe': 'sedan',
#  'a5': 'sedan',
#  'sportage': 'suv',
#  'laguna': 'wagon',
#  'ptcruiser': 'wagon',
#  'clk': 'coupe',
#  'primera': 'sedan',
#  'espace': 'bus',
#  'x_reihe': 'suv',
#  'exeo': 'wagon',
#  '159': 'sedan',
#  'transit': 'bus',
#  'juke': 'small',
#  'carisma': 'sedan',
#  'accord': 'sedan',
#  'corolla': 'wagon',
#  'phaeton': 'sedan',
#  'verso': 'bus',
#  'swift': 'convertible',
#  'rav': 'suv',
#  'qashqai': 'sedan',
#  'picanto': 'small',
#  'boxster': 'convertible',
#  'kalos': 'small',
#  'superb': 'wagon',
#  'stilo': 'wagon',
#  'alhambra': 'bus',
#  'mx_reihe': 'convertible',
#  'roadster': 'convertible',
#  'ypsilon': 'small',
#  'cayenne': 'small',
#  'galant': 'wagon',
#  'justy': 'small',
#  '90': 'coupe',
#  'sirion': 'sedan',
#  'crossfire': 'convertible',
#  'agila': 'small',
#  'duster': 'suv',
#  'v50': 'wagon',
#  '500': 'small',
#  'c_reihe': 'convertible',
#  'v_klasse': 'bus',
#  'm_klasse': 'suv',
#  'yaris': 'small',
#  'c5': 'wagon',
#  'aygo': 'small',
#  'almera': 'sedan',
#  'seicento': 'small',
#  'cc': 'coupe',
#  '911': 'coupe',
#  'bora': 'wagon',
#  'forfour': 'coupe',
#  'm_reihe': 'coupe',
#  '100': 'wagon',
#  'cl': 'coupe',
#  'tigra': 'convertible',
#  '300c': 'sedan',
#  'cr_reihe': 'suv',
#  'spark': 'small',
#  'kuga': 'suv',
#  'x_type': 'sedan',
#  'ducato': 'wagon',
#  's_type': 'sedan',
#  'x_trail': 'suv',
#  'toledo': 'sedan',
#  'altea': 'bus',
#  'voyager': 'bus',
#  'carnival': 'bus',
#  'v70': 'wagon',
#  'bravo': 'small',
#  'antara': 'suv',
#  'tucson': 'suv',
#  'c1': 'small',
#  'citigo': 'small',
#  'jimny': 'suv',
#  'wrangler': 'suv',
#  'lybra': 'wagon',
#  'q7': 'suv',
#  'lancer': 'sedan',
#  'captiva': 'suv',
#  'fusion': 'sedan',
#  'discovery': 'suv',
#  'sandero': 'small',
#  'note': 'bus',
#  '900': 'coupe',
#  'cherokee': 'suv',
#  'clubman': 'wagon',
#  'defender': 'suv',
#  'cx_reihe': 'suv',
#  'legacy': 'wagon',
#  '601': 'wagon',
#  'pajero': 'suv',
#  'c2': 'small',
#  'niva': 'suv',
#  's60': 'sedan',
#  'nubira': 'wagon',
#  'vivaro': 'bus',
#  'lanos': 'sedan',
#  'g_klasse': 'suv',
#  'freelander': 'suv',
#  'auris': 'sedan',
#  'lodgy': 'bus',
#  '850': 'wagon',
#  'range_rover': 'suv',
#  'q3': 'sedan',
#  'serie_2': 'other',
#  'calibra': 'coupe',
#  'glk': 'suv',
#  'charade': 'small',
#  'croma': 'wagon',
#  'outlander': 'wagon',
#  'doblo': 'bus',
#  'musa': 'wagon',
#  'move': 'small',
#  '9000': 'sedan',
#  'v60': 'wagon',
#  '200': 'sedan',
#  '145': 'small',
#  'b_max': 'bus',
#  'range_rover_sport': 'suv',
#  'aveo': 'small',
#  'terios': 'sedan',
#  'rangerover': 'small',
#  'q5': 'suv',
#  'range_rover_evoque': 'suv',
#  'materia': 'sedan',
#  'gl': 'suv',
#  'kalina': 'small',
#  'samara': 'small',
#  'elefantino': 'small',
#  'delta': 'wagon',
#  'i3': 'convertible',
#  'amarok': 'suv',
#  'kappa': 'sedan',
#  'serie_3': 'suv',
#  'serie_1': 'wagon'}

# %%
# Filling missing VehicleTypes using the dict
df['VehicleType'] = df['VehicleType'].fillna(df['Model'].map(model_type_dict))
df['VehicleType'].isna().sum()
# Out:
# 6827

# %%
# Filling the rest of NaN values with 'unknown'
df.fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# DateCrawled          0
# Price                0
# VehicleType          0
# RegistrationYear     0
# Gearbox              0
# Power                0
# Model                0
# Mileage              0
# RegistrationMonth    0
# FuelType             0
# Brand                0
# NotRepaired          0
# DateCreated          0
# NumberOfPictures     0
# PostalCode           0
# LastSeen             0
# dtype: int64

# %% [markdown]
# ## Treating impossible values
#
# ### Registration date

# %%
df.sort_values(by='DateCrawled')
# Out:
#              DateCrawled  Price VehicleType  RegistrationYear  Gearbox  Power  \
# 44605   01/04/2016 00:06   7500       sedan              2000     auto    306
# 266309  01/04/2016 00:06   8700         bus              2009     auto    147
# 157575  01/04/2016 00:06   2900       wagon              2000     auto    279
# 119464  01/04/2016 00:10   4899       wagon              2001   manual    231
# 122961  01/04/2016 00:25  13500         suv              2012     auto    156
# ...                  ...    ...         ...               ...      ...    ...
# 78345   31/03/2016 23:58      0       small              2018  unknown      0
# 345137  31/03/2016 23:58   1199       small              2001   manual     75
# 102507  31/03/2016 23:58    120       small              1999   manual     54
# 59100   31/03/2016 23:58   8500       coupe              1988     auto    132
# 201546  31/03/2016 23:58   3399         bus              2001   manual      0
#
#             Model  Mileage  RegistrationMonth  FuelType          Brand  \
# 44605    s_klasse   150000                  3    petrol  mercedes_benz
# 266309      verso   150000                 10    petrol         toyota
# 157575   e_klasse   150000                 10       lpg  mercedes_benz
# 119464        3er   150000                  3    petrol            bmw
# 122961  outlander   125000                  1  gasoline     mitsubishi
# ...           ...      ...                ...       ...            ...
# 78345          c2   150000                  0   unknown        citroen
# 345137       lupo   150000                 11    petrol     volkswagen
# 102507      other   150000                  0    petrol          skoda
# 59100       other    50000                  4    petrol  mercedes_benz
# 201546   alhambra   150000                 11  gasoline           seat
#
#        NotRepaired       DateCreated  NumberOfPictures  PostalCode  \
# 44605           no  31/03/2016 00:00                 0       61169
# 266309          no  31/03/2016 00:00                 0       57080
# 157575         yes  31/03/2016 00:00                 0       55118
# 119464          no  30/03/2016 00:00                 0       57539
# 122961          no  31/03/2016 00:00                 0       61191
# ...            ...               ...               ...         ...
# 78345      unknown  31/03/2016 00:00                 0       49610
# 345137         yes  31/03/2016 00:00                 0       91177
# 102507     unknown  31/03/2016 00:00                 0       84529
# 59100           no  31/03/2016 00:00                 0       70437
# 201546         yes  31/03/2016 00:00                 0       97424
#
#                 LastSeen
# 44605   01/04/2016 03:06
# 266309  06/04/2016 17:44
# 157575  06/04/2016 17:44
# 119464  07/04/2016 05:46
# 122961  02/04/2016 18:10
# ...                  ...
# 78345   07/04/2016 04:16
# 345137  07/04/2016 04:16
# 102507  07/04/2016 04:16
# 59100   01/04/2016 07:44
# 201546  07/04/2016 04:16
#
# [354107 rows x 16 columns]

# %%
df[df['RegistrationYear'] < 1900]['RegistrationYear'].value_counts().sort_index()
# Out:
# 1000    37
# 1001     1
# 1039     1
# 1111     3
# 1200     1
# 1234     4
# 1253     1
# 1255     1
# 1300     2
# 1400     1
# 1500     5
# 1600     2
# 1602     1
# 1688     1
# 1800     5
# Name: RegistrationYear, dtype: int64

# %% [markdown]
# The last entry in this dataset was obtained in April 2016, so we will drop rows with `RegistrationYear` values that go beyond this date. As for the bottom limit, we will use the year `1900`.
#
# Impossible values in `RegistrationMonth` will also be dropped.

# %%
shape_pre = df.shape[0]
print('Rows before dropping:', shape_pre)

# Dropping rows with impossible years
df = df[(df['RegistrationYear'] > 1900) & (df['RegistrationYear'] < 2016)]

# Dropping rows with impossible months
df = df[(df['RegistrationMonth'] > 0) & (df['RegistrationMonth'] < 13)]

# Dropping rows with impossible months in 2016
df = df.drop(df[(df['RegistrationYear'] == 2016) & (df['RegistrationMonth'] > 4)].index)

shape_post = df.shape[0]
print('Dropped rows:', shape_pre - shape_post)
print('Rows after dropping:', shape_post)
# Out:
# Rows before dropping: 354107
# Dropped rows: 55050
# Rows after dropping: 299057

# %% [markdown]
# ### `Power` & `Price`

# %% [markdown]
# Because it's difficult to pinpoint the exact limits of possible values in these columns, we will identify and remove outliers using statistics.

# %%
# Removing outliers in `Power`

shape_pre = df.shape[0]
print('Rows before dropping:', shape_pre)

Q1 = df['Power'].quantile(0.25)
Q3 = df['Power'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - IQR
upper_bound = Q3 + IQR

df = df[(df['Power'] >= lower_bound) & (df['Power'] <=  upper_bound)] 

shape_post = df.shape[0]
print('Dropped rows:', shape_pre - shape_post)
print('Rows after dropping:', shape_post)
# Out:
# Rows before dropping: 299057
# Dropped rows: 38779
# Rows after dropping: 260278

# %%
# Removing outliers in `Price`

shape_pre = df.shape[0]
print('Rows before dropping:', shape_pre)

Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - IQR
upper_bound = Q3 + IQR

df = df[(df['Price'] >= lower_bound) & (df['Price'] <= upper_bound)] 

shape_post = df.shape[0]
print('Dropped rows:', shape_pre - shape_post)
print('Rows after dropping:', shape_post)
# Out:
# Rows before dropping: 260278
# Dropped rows: 23973
# Rows after dropping: 236305

# %% [markdown]
# ## Dropping insignificant features
#
# `DateCrawled`, `DateCreated`, `LastSeen`, `PostalCode`, and `NumberOfPictures` won't contribute to price predictions. We will drop them.

# %%
df.drop(['DateCrawled', 'DateCreated', 'LastSeen', 'PostalCode', 'NumberOfPictures'], axis=1, inplace=True)
df.shape
# Out:
# (236305, 11)

# %%
df.columns
# Out:
# Index(['Price', 'VehicleType', 'RegistrationYear', 'Gearbox', 'Power', 'Model',
#        'Mileage', 'RegistrationMonth', 'FuelType', 'Brand', 'NotRepaired'],
#       dtype='object')

# %% [markdown]
# ## Checking data types
#
# model numerical data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236305 entries, 2 to 354368
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Price              236305 non-null  int64
#  1   VehicleType        236305 non-null  object
#  2   RegistrationYear   236305 non-null  int64
#  3   Gearbox            236305 non-null  object
#  4   Power              236305 non-null  int64
#  5   Model              236305 non-null  object
#  6   Mileage            236305 non-null  int64
#  7   RegistrationMonth  236305 non-null  int64
#  8   FuelType           236305 non-null  object
#  9   Brand              236305 non-null  object
#  10  NotRepaired        236305 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 21.6+ MB

# %% [markdown]
# ## Non-ordinal categorical feature encoding
#
# ML models can only process numerical data. We can represent our categorical data numerically by encoding them. Because most of our categorical features are not ordinal, ordinal encoding is very likely to distort ML predictions. We will use one-hot encoding (OHE) instead.

# %%
# Specifying columns to encode
columns_to_encode = ['VehicleType', 'Gearbox', 'Power', 'Model', 'FuelType', 'Brand', 'NotRepaired']
other_columns = ['RegistrationYear', 'Mileage', 'RegistrationMonth', 'Price']

# Transforming non-ordinal categorical columns
# drop_first=True to prevent redundancy
df_encoded = df[columns_to_encode]
df_encoded = pd.get_dummies(df_encoded, drop_first=True)
print('df_encoded size:', df_encoded.shape)

# Appending non-encoded columns to the df
df_encoded[other_columns] = df[other_columns]
print('Complete df_encoded size:', df_encoded.shape)
# Out:
# df_encoded size: (236305, 304)
# Complete df_encoded size: (236305, 308)

# %% [markdown]
# ## Training and test set splitting
#
# We will divide the full set into two: one for training and another for testing, with a ratio of 70:30.

# %%
df_train, df_test = train_test_split(df_encoded, train_size=0.7, random_state=random_state)
print('df_train size:', df_train.shape)
print('df_test size:', df_test.shape)
# Out:
# df_train size: (165413, 308)
# df_test size: (70892, 308)

# %% [markdown]
# ## Feature and target separation
#
# `Price` is our target. We will separate it from the features.

# %%
train_target = df_train['Price']
train_features = df_train.drop('Price', axis=1)

test_target = df_test['Price']
test_features = df_test.drop('Price', axis=1)

# %% [markdown]
# ## Data preprocessing summary
#
# In this stage, we made the following changes:
# - removed 262 duplicate rows,
# - filled 30,657 missing `VehicleType`s with data from available models,
# - filled every other missing value with `unknown` placeholder category ,
# - removed rows with registration year before 1900 and after April 2016,
# - removed rows with outlier values in `Power` and `Price`,
# - dropped features that would not contribute to machine learning,
# - encoded non-ordinal categorical variables with one-hot encoding.
#
# These actions resulted in a dataset of 236,305 rows (removing 118,064 rows, approximately 33% of the original size) and 308 columns.
#
# Finally, we separated the features from the target.

# %% [markdown]
# # Model creation, training, and testing
#
# We're ready to create predictor models for Rusty Bargain. We'll compare several algorithms: linear, decision tree, and random forest regressors, and several implementations of gradient boosting algorithms. The models will be trained and cross-validated with the full dataset. As a measure of the models' performance, we will use their calculation speed and root of mean squared error (RMSE).

# %% [markdown]
# ## Creating a dictionary to store model performance information
#
# At the end of this project, we'll have to compare the performance of all models. We will create an empty dictionary to store this information along the way.

# %%
performance_dict = {}
performance_columns = ['Training time', 'Test time', 'Training score', 'Test score']

# %% [markdown]
# ## Linear regression
#
# Due to its low configurability and simple algorithm, this model will serve as a measure of sanity check for the other models.

# %%
# Creating an instance of the linear regressor model
lr = LinearRegression()

# Fitting
print('Training')

## Recording start time
start = time.process_time()

lr.fit(train_features, train_target)

## Recording end time and storing it
end = time.process_time()
lr_train_time = end - start

print('Training CPU execution time:', lr_train_time)

pred = lr.predict(train_features)
lr_train_score = (mse(train_target, pred) ** 0.5)
print('Training score:', lr_train_score)

print()

# Testing
print('Testing')

## Getting test time
start = time.process_time()

pred = lr.predict(test_features)

## Recording end time and storing it
end = time.process_time()
lr_test_time = end - start

print('Test prediction CPU execution time:', lr_test_time)

## Getting test score
lr_test_score = (mse(test_target, pred) ** 0.5)
print('Test score:', lr_test_score)

# Storing information in the performance dictionary
performance_dict['lr'] = [lr_train_time, lr_test_time, lr_train_score, lr_test_score]
# Out:
# Training
# Training CPU execution time: 34.03125
# Training score: 1758.9908905595864
#
# Testing
# Test prediction CPU execution time: 0.15625
# Test score: 1742.2336664346026

# %% [markdown]
# ## Decision tree regressor
#
# We can tune the `max_depth` hyperparameter for this model.

# %%
# Creating variables to store best scores and time
dtr_best_train_score = 99999
dtr_best_test_score = 99999
dtr_best_train_time = 99999
dtr_best_test_time = 99999
dtr_best_model = None

# Creating instances of the decision tree model with varying hyperparameters
for depth in range(1, 15):
    dtr = DecisionTreeRegressor(max_depth=depth, random_state=random_state)

    # Fitting   
    ## Recording start time
    start = time.process_time()

    dtr.fit(train_features, train_target)

    ## Recording end time and storing it
    end = time.process_time()
    dtr_train_time = end - start
    
    pred = dtr.predict(train_features)
    dtr_train_score = (mse(train_target, pred) ** 0.5)
    
    # Testing   
    ## Recording start time
    start = time.process_time()

    pred = dtr.predict(test_features)

    ## Recording end time and storing it
    end = time.process_time()
    dtr_test_time = end - start
    
    dtr_test_score = (mse(test_target, pred) ** 0.5)
    
    # Storing best max_depth and scores
    if dtr_test_score < dtr_best_test_score:
        dtr_best_train_time = dtr_train_time
        dtr_best_test_time = dtr_test_time
        dtr_best_train_score = dtr_train_score
        dtr_best_test_score = dtr_test_score
        dtr_best_model = dtr

# Storing information in the performance dictionary
performance_dict['dtr'] = [dtr_best_train_time, dtr_best_test_time, dtr_best_train_score, dtr_best_test_score]
    
# Printing best depth and scores
print('Best training time:', dtr_best_train_time)
print('Best test time:', dtr_best_test_time)
print('Best training score:', dtr_best_train_score)
print('Best test score:', dtr_best_test_score)
print('Best model & hyperparameters:')
dtr_best_model
# Out:
# Best training time: 3.671875
# Best test time: 0.125
# Best training score: 1159.8168895706096
# Best test score: 1356.9307257119617
# Best model & hyperparameters:
# DecisionTreeRegressor(max_depth=14, random_state=12345)

# %% [markdown]
# ## Random forest regressor
#
# This model has 2 hyperparameters we can tune:
# - `n_estimators`, from 1 to 100 with an increment of 25 in each iteration
# - `max_depth`, the same as before (1--15) with an increment of 5 in each iteration

# %%
# Creating variables to store best scores
rfr_best_train_score = 99999
rfr_best_test_score = 99999
rfr_best_train_time = 99999
rfr_best_test_time = 99999
rfr_best_model = None

# Increasing the number of estimators from 1 to 100 by 25 in each loop
for estimators in range(1, 101, 25):
    # Increasing the depth from 1 to 15 by 5 in each loop 
    for depth in range(1, 15, 5):
        # Creating instances of LGBMRegressor with varying hyperparameters
        rfr = RandomForestRegressor(n_estimators=estimators, max_depth=depth, random_state=random_state)

        # Fitting   
        ## Recording start time
        start = time.process_time()

        rfr.fit(train_features, train_target)

        ## Recording end time and storing it
        end = time.process_time()
        rfr_train_time = end - start

        pred = rfr.predict(train_features)
        rfr_train_score = (mse(train_target, pred) ** 0.5)

        # Testing   
        ## Recording start time
        start = time.process_time()

        pred = rfr.predict(test_features)

        ## Recording end time and storing it
        end = time.process_time()
        rfr_test_time = end - start

        rfr_test_score = (mse(test_target, pred) ** 0.5)

        # Storing best max_depth and scores
        if rfr_test_score < rfr_best_test_score:
            rfr_best_train_time = rfr_train_time
            rfr_best_test_time = rfr_test_time
            rfr_best_train_score = rfr_train_score
            rfr_best_test_score = rfr_test_score
            rfr_best_model = rfr
    
# Storing information in the performance dictionary
performance_dict['rfr'] = [rfr_best_train_time, rfr_best_test_time, rfr_best_train_score, rfr_best_test_score]
    
# Printing best hyperparameters and scores
print('Best training time:', rfr_best_train_time)
print('Best test time:', rfr_best_test_time)
print('Best training score:', rfr_best_train_score)
print('Best test score:', rfr_best_test_score)
print('Best model & hyperparameters:')
rfr_best_model
# Out:
# Best training time: 152.34375
# Best test time: 0.59375
# Best training score: 1261.8176282736492
# Best test score: 1332.5585663830586
# Best model & hyperparameters:
# RandomForestRegressor(max_depth=11, n_estimators=76, random_state=12345)

# %% [markdown]
# ## Gradient-boosting algorithms
#
# We will try and compare 3 implementations of gradient-boosting algorithms: XGBoost, LightGBM, and CatBoost. Being the different implementations of similar algorithms, these 3 models have similar tunable hyperparameters:
# - `n_estimators`
# - `max_depth`
#
# Note that these models have built-in overfitting detectors that can stop model training when the optimum hyperparameters have been reached. However, because we tune our hyperparameters manually (instead of letting the model do it on its own), we cannot use this feature.

# %% [markdown]
# ### XGBoost Regressor

# %%
# Creating variables to store best scores
xgbr_best_train_score = 99999
xgbr_best_test_score = 99999
xgbr_best_train_time = 99999
xgbr_best_test_time = 99999
xgbr_best_model = None

# Increasing the number of estimators from 1 to 100 by 25 in each loop
for estimators in range(1, 101, 25):
    # Increasing the depth from 1 to 15 by 5 in each loop 
    for depth in range(1, 15, 5):
        # Creating instances of LGBMRegressor with varying hyperparameters
        xgbr = XGBRegressor(n_estimators=estimators, max_depth=depth, random_state=random_state)

        # Fitting   
        ## Recording start time
        start = time.process_time()

        xgbr.fit(train_features, train_target)

        ## Recording end time and storing it
        end = time.process_time()
        xgbr_train_time = end - start

        pred = xgbr.predict(train_features)
        xgbr_train_score = (mse(train_target, pred) ** 0.5)

        # Testing   
        ## Recording start time
        start = time.process_time()

        pred = xgbr.predict(test_features)

        ## Recording end time and storing it
        end = time.process_time()
        xgbr_test_time = end - start

        xgbr_test_score = (mse(test_target, pred) ** 0.5)

        # Storing best max_depth and scores
        if xgbr_test_score < xgbr_best_test_score:
            xgbr_best_train_time = xgbr_train_time
            xgbr_best_test_time = xgbr_test_time
            xgbr_best_train_score = xgbr_train_score
            xgbr_best_test_score = xgbr_test_score
            xgbr_best_model = xgbr
    
# Storing information in the performance dictionary
performance_dict['xgbr'] = [xgbr_best_train_time, xgbr_best_test_time, xgbr_best_train_score, xgbr_best_test_score]
    
# Printing best hyperparameters and scores
print('Best training time:', xgbr_best_train_time)
print('Best test time:', xgbr_best_test_time)
print('Best training score:', xgbr_best_train_score)
print('Best test score:', xgbr_best_test_score)
print('Best model & hyperparameters:')
xgbr_best_model
# Out:
# Best training time: 580.59375
# Best test time: 2.078125
# Best training score: 934.1587388302968
# Best test score: 1160.4868796934459
# Best model & hyperparameters:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=11, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=76, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=12345, ...)

# %% [markdown]
# ### LightGBM Regressor

# %%
# Creating variables to store best scores
lgbmr_best_train_score = 99999
lgbmr_best_test_score = 99999
lgbmr_best_train_time = 99999
lgbmr_best_test_time = 99999
lgbmr_best_model = None

# Increasing the number of estimators from 1 to 100 by 25 in each loop
for estimators in range(1, 101, 25):
    # Increasing the depth from 1 to 15 by 5 in each loop 
    for depth in range(1, 15, 5):
        # Creating instances of LGBMRegressor with varying hyperparameters
        lgbmr = LGBMRegressor(n_estimators=estimators, max_depth=depth, random_state=random_state)

        # Fitting   
        ## Recording start time
        start = time.process_time()

        lgbmr.fit(train_features, train_target)

        ## Recording end time and storing it
        end = time.process_time()
        lgbmr_train_time = end - start

        pred = lgbmr.predict(train_features)
        lgbmr_train_score = (mse(train_target, pred) ** 0.5)

        # Testing   
        ## Recording start time
        start = time.process_time()

        pred = lgbmr.predict(test_features)

        ## Recording end time and storing it
        end = time.process_time()
        lgbmr_test_time = end - start

        lgbmr_test_score = (mse(test_target, pred) ** 0.5)

        # Storing best max_depth and scores
        if lgbmr_test_score < lgbmr_best_test_score:
            lgbmr_best_train_time = lgbmr_train_time
            lgbmr_best_test_time = lgbmr_test_time
            lgbmr_best_train_score = lgbmr_train_score
            lgbmr_best_test_score = lgbmr_test_score
            lgbmr_best_model = lgbmr
    
# Storing information in the performance dictionary
performance_dict['lgbmr'] = [lgbmr_best_train_time, lgbmr_best_test_time, lgbmr_best_train_score, lgbmr_best_test_score]
    
# Printing best hyperparameters and scores
print('Best training score:', lgbmr_best_train_score)
print('Best test score:', lgbmr_best_test_score)
print('Best training time:', lgbmr_best_train_time)
print('Best test time:', lgbmr_best_test_time)
print('Best model & hyperparameters:')
lgbmr_best_model
# Out:
# Best training score: 1232.4583742616953
# Best test score: 1245.8386318333496
# Best training time: 8.625
# Best test time: 1.5
# Best model & hyperparameters:
# LGBMRegressor(max_depth=11, n_estimators=76, random_state=12345)

# %% [markdown]
# ### CatBoost Regressor

# %%
# Creating variables to store best scores
cbr_best_depth = 99999
cbr_best_train_score = 99999
cbr_best_test_score = 99999
cbr_best_train_time = 99999
cbr_best_test_time = 99999
cbr_best_model = None

# Increasing the number of estimators from 1 to 100 by 25 in each loop
for estimators in range(1, 101, 25):
    # Increasing the depth from 1 to 15 by 5 in each loop 
    for depth in range(1, 15, 5):
        # Creating instances of LGBMRegressor with varying hyperparameters
        cbr = CatBoostRegressor(n_estimators=estimators, max_depth=depth, random_state=random_state)

        # Fitting   
        ## Recording start time
        start = time.process_time()

        cbr.fit(train_features, train_target)

        ## Recording end time and storing it
        end = time.process_time()
        cbr_train_time = end - start

        pred = cbr.predict(train_features)
        cbr_train_score = (mse(train_target, pred) ** 0.5)

        # Testing   
        ## Recording start time
        start = time.process_time()

        pred = cbr.predict(test_features)

        ## Recording end time and storing it
        end = time.process_time()
        cbr_test_time = end - start

        cbr_test_score = (mse(test_target, pred) ** 0.5)

        # Storing best max_depth and scores
        if cbr_test_score < cbr_best_test_score:
            cbr_best_train_time = cbr_train_time
            cbr_best_test_time = cbr_test_time
            cbr_best_train_score = cbr_train_score
            cbr_best_test_score = cbr_test_score
            cbr_best_model = cbr
    
# Storing information in the performance dictionary
performance_dict['cbr'] = [cbr_best_train_time, cbr_best_test_time, cbr_best_train_score, cbr_best_test_score]
    
# Printing best hyperparameters and scores
print('Best training time:', cbr_best_train_time)
print('Best test time:', cbr_best_test_time)
print('Best training score:', cbr_best_train_score)
print('Best test score:', cbr_best_test_score)
print('Best model & hyperparameters:')
cbr_best_model
# Out:
# Learning rate set to 0.5
# 0:	learn: 2406.4211772	total: 171ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2130.0072082	total: 12.8ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2029.4776431	total: 44.8ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2406.4211772	total: 7.8ms	remaining: 195ms
# 1:	learn: 2217.2267645	total: 13.8ms	remaining: 166ms
# 2:	learn: 2085.8440761	total: 19.8ms	remaining: 152ms
# 3:	learn: 1997.3952233	total: 25.9ms	remaining: 142ms
# 4:	learn: 1938.0498667	total: 31.9ms	remaining: 134ms
# 5:	learn: 1883.4384461	total: 37.9ms	remaining: 126ms
# 6:	learn: 1849.2587724	total: 44.1ms	remaining: 120ms
# 7:	learn: 1820.8434109	total: 50.7ms	remaining: 114ms
# 8:	learn: 1794.0602806	total: 56.9ms	remaining: 108ms
# 9:	learn: 1772.7863433	total: 62.9ms	remaining: 101ms
# 10:	learn: 1752.5147970	total: 69.2ms	remaining: 94.4ms
# 11:	learn: 1733.8716098	total: 75.4ms	remaining: 88ms
# 12:	learn: 1715.7296139	total: 81.8ms	remaining: 81.8ms
# 13:	learn: 1702.3783414	total: 88.5ms	remaining: 75.9ms
# 14:	learn: 1690.8715367	total: 95.2ms	remaining: 69.8ms
# 15:	learn: 1680.8837492	total: 105ms	remaining: 65.3ms
# 16:	learn: 1672.6476994	total: 114ms	remaining: 60.3ms
# 17:	learn: 1664.0680797	total: 122ms	remaining: 54.4ms
# 18:	learn: 1656.4018572	total: 130ms	remaining: 48ms
# 19:	learn: 1648.5014491	total: 138ms	remaining: 41.3ms
# 20:	learn: 1640.8418544	total: 146ms	remaining: 34.7ms
# 21:	learn: 1634.5721370	total: 154ms	remaining: 28ms
# 22:	learn: 1627.9276207	total: 160ms	remaining: 20.8ms
# 23:	learn: 1621.2667428	total: 166ms	remaining: 13.8ms
# 24:	learn: 1614.5775579	total: 172ms	remaining: 6.89ms
# 25:	learn: 1608.1598336	total: 179ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2130.0072082	total: 12.8ms	remaining: 321ms
# 1:	learn: 1793.5278272	total: 24.9ms	remaining: 298ms
# 2:	learn: 1621.5894609	total: 37.1ms	remaining: 284ms
# 3:	learn: 1524.1163768	total: 49.4ms	remaining: 272ms
# 4:	learn: 1473.5523643	total: 61.9ms	remaining: 260ms
# 5:	learn: 1441.9152850	total: 74.7ms	remaining: 249ms
# 6:	learn: 1425.6852057	total: 87.1ms	remaining: 236ms
# 7:	learn: 1400.6361759	total: 99.9ms	remaining: 225ms
# 8:	learn: 1384.3662931	total: 113ms	remaining: 213ms
# 9:	learn: 1372.9725639	total: 125ms	remaining: 200ms
# 10:	learn: 1361.8885555	total: 139ms	remaining: 189ms
# 11:	learn: 1354.0831876	total: 153ms	remaining: 179ms
# 12:	learn: 1348.8680810	total: 170ms	remaining: 170ms
# 13:	learn: 1340.6743638	total: 185ms	remaining: 158ms
# 14:	learn: 1336.6554873	total: 198ms	remaining: 145ms
# 15:	learn: 1331.4751500	total: 212ms	remaining: 132ms
# 16:	learn: 1324.6551759	total: 227ms	remaining: 120ms
# 17:	learn: 1319.6440221	total: 242ms	remaining: 107ms
# 18:	learn: 1314.1558412	total: 258ms	remaining: 95ms
# 19:	learn: 1310.6278324	total: 274ms	remaining: 82.1ms
# 20:	learn: 1307.8614767	total: 290ms	remaining: 69.1ms
# 21:	learn: 1303.8014120	total: 306ms	remaining: 55.6ms
# 22:	learn: 1300.0992097	total: 323ms	remaining: 42.1ms
# 23:	learn: 1294.3632411	total: 340ms	remaining: 28.3ms
# 24:	learn: 1292.3750784	total: 355ms	remaining: 14.2ms
# 25:	learn: 1289.3646059	total: 369ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2029.4776431	total: 44ms	remaining: 1.1s
# 1:	learn: 1631.6784275	total: 88.3ms	remaining: 1.06s
# 2:	learn: 1472.5348848	total: 132ms	remaining: 1.01s
# 3:	learn: 1395.3600845	total: 181ms	remaining: 996ms
# 4:	learn: 1361.6563124	total: 225ms	remaining: 945ms
# 5:	learn: 1328.3983622	total: 267ms	remaining: 892ms
# 6:	learn: 1313.6914512	total: 315ms	remaining: 854ms
# 7:	learn: 1297.3681380	total: 366ms	remaining: 822ms
# 8:	learn: 1288.2972502	total: 411ms	remaining: 776ms
# 9:	learn: 1279.3144794	total: 457ms	remaining: 730ms
# 10:	learn: 1265.5631479	total: 503ms	remaining: 686ms
# 11:	learn: 1253.3057646	total: 549ms	remaining: 640ms
# 12:	learn: 1248.2299516	total: 599ms	remaining: 599ms
# 13:	learn: 1243.5001143	total: 647ms	remaining: 554ms
# 14:	learn: 1238.8202857	total: 693ms	remaining: 508ms
# 15:	learn: 1233.3917725	total: 739ms	remaining: 462ms
# 16:	learn: 1228.8472896	total: 785ms	remaining: 416ms
# 17:	learn: 1225.2040708	total: 835ms	remaining: 371ms
# 18:	learn: 1223.3409357	total: 882ms	remaining: 325ms
# 19:	learn: 1218.4223186	total: 928ms	remaining: 278ms
# 20:	learn: 1213.3690244	total: 975ms	remaining: 232ms
# 21:	learn: 1208.1009656	total: 1.02s	remaining: 186ms
# 22:	learn: 1205.0800772	total: 1.07s	remaining: 140ms
# 23:	learn: 1201.5471045	total: 1.12s	remaining: 93.5ms
# 24:	learn: 1197.8432879	total: 1.17s	remaining: 46.8ms
# 25:	learn: 1194.6919759	total: 1.21s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2406.4211772	total: 6.75ms	remaining: 338ms
# 1:	learn: 2217.2267645	total: 12.5ms	remaining: 307ms
# 2:	learn: 2085.8440761	total: 18.6ms	remaining: 297ms
# 3:	learn: 1997.3952233	total: 24.9ms	remaining: 293ms
# 4:	learn: 1938.0498667	total: 31.1ms	remaining: 286ms
# 5:	learn: 1883.4384461	total: 37.3ms	remaining: 280ms
# 6:	learn: 1849.2587724	total: 43.6ms	remaining: 274ms
# 7:	learn: 1820.8434109	total: 49.9ms	remaining: 268ms
# 8:	learn: 1794.0602806	total: 56.9ms	remaining: 265ms
# 9:	learn: 1772.7863433	total: 63.7ms	remaining: 261ms
# 10:	learn: 1752.5147970	total: 70.5ms	remaining: 256ms
# 11:	learn: 1733.8716098	total: 76.8ms	remaining: 250ms
# 12:	learn: 1715.7296139	total: 83.6ms	remaining: 244ms
# 13:	learn: 1702.3783414	total: 90ms	remaining: 238ms
# 14:	learn: 1690.8715367	total: 96.5ms	remaining: 232ms
# 15:	learn: 1680.8837492	total: 103ms	remaining: 226ms
# 16:	learn: 1672.6476994	total: 110ms	remaining: 220ms
# 17:	learn: 1664.0680797	total: 116ms	remaining: 213ms
# 18:	learn: 1656.4018572	total: 123ms	remaining: 206ms
# 19:	learn: 1648.5014491	total: 129ms	remaining: 199ms
# 20:	learn: 1640.8418544	total: 135ms	remaining: 193ms
# 21:	learn: 1634.5721370	total: 141ms	remaining: 186ms
# 22:	learn: 1627.9276207	total: 149ms	remaining: 181ms
# 23:	learn: 1621.2667428	total: 156ms	remaining: 175ms
# 24:	learn: 1614.5775579	total: 163ms	remaining: 170ms
# 25:	learn: 1608.1598336	total: 172ms	remaining: 165ms
# 26:	learn: 1602.1699434	total: 179ms	remaining: 159ms
# 27:	learn: 1596.8080985	total: 188ms	remaining: 154ms
# 28:	learn: 1592.6989582	total: 195ms	remaining: 148ms
# 29:	learn: 1589.0137758	total: 203ms	remaining: 142ms
# 30:	learn: 1585.1381295	total: 210ms	remaining: 136ms
# 31:	learn: 1581.5594030	total: 219ms	remaining: 130ms
# 32:	learn: 1578.3836900	total: 225ms	remaining: 123ms
# 33:	learn: 1575.1620215	total: 233ms	remaining: 116ms
# 34:	learn: 1571.9506771	total: 240ms	remaining: 110ms
# 35:	learn: 1568.9659919	total: 247ms	remaining: 103ms
# 36:	learn: 1565.9293408	total: 254ms	remaining: 96.3ms
# 37:	learn: 1562.9971077	total: 262ms	remaining: 89.5ms
# 38:	learn: 1560.2785103	total: 268ms	remaining: 82.6ms
# 39:	learn: 1557.3886897	total: 275ms	remaining: 75.6ms
# 40:	learn: 1554.8247207	total: 281ms	remaining: 68.6ms
# 41:	learn: 1552.2108680	total: 288ms	remaining: 61.7ms
# 42:	learn: 1549.3831436	total: 294ms	remaining: 54.7ms
# 43:	learn: 1547.1451838	total: 301ms	remaining: 47.9ms
# 44:	learn: 1545.0411475	total: 308ms	remaining: 41.1ms
# 45:	learn: 1543.0603033	total: 315ms	remaining: 34.2ms
# 46:	learn: 1541.1280032	total: 321ms	remaining: 27.4ms
# 47:	learn: 1539.2095697	total: 328ms	remaining: 20.5ms
# 48:	learn: 1537.4185356	total: 335ms	remaining: 13.7ms
# 49:	learn: 1535.7133770	total: 341ms	remaining: 6.82ms
# 50:	learn: 1533.9857888	total: 349ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2130.0072082	total: 12.7ms	remaining: 634ms
# 1:	learn: 1793.5278272	total: 23.6ms	remaining: 578ms
# 2:	learn: 1621.5894609	total: 35.6ms	remaining: 569ms
# 3:	learn: 1524.1163768	total: 49.2ms	remaining: 578ms
# 4:	learn: 1473.5523643	total: 63.4ms	remaining: 583ms
# 5:	learn: 1441.9152850	total: 77ms	remaining: 577ms
# 6:	learn: 1425.6852057	total: 89.4ms	remaining: 562ms
# 7:	learn: 1400.6361759	total: 103ms	remaining: 553ms
# 8:	learn: 1384.3662931	total: 117ms	remaining: 545ms
# 9:	learn: 1372.9725639	total: 132ms	remaining: 539ms
# 10:	learn: 1361.8885555	total: 148ms	remaining: 537ms
# 11:	learn: 1354.0831876	total: 163ms	remaining: 528ms
# 12:	learn: 1348.8680810	total: 175ms	remaining: 513ms
# 13:	learn: 1340.6743638	total: 190ms	remaining: 502ms
# 14:	learn: 1336.6554873	total: 203ms	remaining: 488ms
# 15:	learn: 1331.4751500	total: 217ms	remaining: 475ms
# 16:	learn: 1324.6551759	total: 232ms	remaining: 465ms
# 17:	learn: 1319.6440221	total: 247ms	remaining: 452ms
# 18:	learn: 1314.1558412	total: 261ms	remaining: 440ms
# 19:	learn: 1310.6278324	total: 275ms	remaining: 426ms
# 20:	learn: 1307.8614767	total: 289ms	remaining: 413ms
# 21:	learn: 1303.8014120	total: 305ms	remaining: 401ms
# 22:	learn: 1300.0992097	total: 320ms	remaining: 389ms
# 23:	learn: 1294.3632411	total: 334ms	remaining: 376ms
# 24:	learn: 1292.3750784	total: 347ms	remaining: 361ms
# 25:	learn: 1289.3646059	total: 362ms	remaining: 348ms
# 26:	learn: 1286.3501071	total: 377ms	remaining: 335ms
# 27:	learn: 1282.2615637	total: 391ms	remaining: 321ms
# 28:	learn: 1279.2623059	total: 405ms	remaining: 307ms
# 29:	learn: 1277.0224722	total: 418ms	remaining: 293ms
# 30:	learn: 1274.7965468	total: 432ms	remaining: 279ms
# 31:	learn: 1271.6080797	total: 447ms	remaining: 265ms
# 32:	learn: 1268.6940737	total: 462ms	remaining: 252ms
# 33:	learn: 1266.2131057	total: 476ms	remaining: 238ms
# 34:	learn: 1263.3763725	total: 490ms	remaining: 224ms
# 35:	learn: 1261.4335802	total: 504ms	remaining: 210ms
# 36:	learn: 1258.8367404	total: 518ms	remaining: 196ms
# 37:	learn: 1256.5327484	total: 533ms	remaining: 182ms
# 38:	learn: 1254.7065348	total: 546ms	remaining: 168ms
# 39:	learn: 1253.3726375	total: 559ms	remaining: 154ms
# 40:	learn: 1251.0831334	total: 574ms	remaining: 140ms
# 41:	learn: 1248.9929017	total: 591ms	remaining: 127ms
# 42:	learn: 1247.0725458	total: 604ms	remaining: 112ms
# 43:	learn: 1245.8116388	total: 618ms	remaining: 98.3ms
# 44:	learn: 1244.4398730	total: 631ms	remaining: 84.2ms
# 45:	learn: 1241.5859517	total: 646ms	remaining: 70.2ms
# 46:	learn: 1239.4527432	total: 660ms	remaining: 56.2ms
# 47:	learn: 1237.5775657	total: 674ms	remaining: 42.1ms
# 48:	learn: 1236.0676801	total: 689ms	remaining: 28.1ms
# 49:	learn: 1234.0367101	total: 703ms	remaining: 14.1ms
# 50:	learn: 1233.6934615	total: 716ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2029.4776431	total: 43.5ms	remaining: 2.17s
# 1:	learn: 1631.6784275	total: 93.7ms	remaining: 2.29s
# 2:	learn: 1472.5348848	total: 140ms	remaining: 2.24s
# 3:	learn: 1395.3600845	total: 187ms	remaining: 2.2s
# 4:	learn: 1361.6563124	total: 231ms	remaining: 2.13s
# 5:	learn: 1328.3983622	total: 277ms	remaining: 2.08s
# 6:	learn: 1313.6914512	total: 322ms	remaining: 2.02s
# 7:	learn: 1297.3681380	total: 373ms	remaining: 2.01s
# 8:	learn: 1288.2972502	total: 419ms	remaining: 1.96s
# 9:	learn: 1279.3144794	total: 464ms	remaining: 1.9s
# 10:	learn: 1265.5631479	total: 510ms	remaining: 1.85s
# 11:	learn: 1253.3057646	total: 555ms	remaining: 1.8s
# 12:	learn: 1248.2299516	total: 603ms	remaining: 1.76s
# 13:	learn: 1243.5001143	total: 649ms	remaining: 1.72s
# 14:	learn: 1238.8202857	total: 697ms	remaining: 1.67s
# 15:	learn: 1233.3917725	total: 744ms	remaining: 1.63s
# 16:	learn: 1228.8472896	total: 789ms	remaining: 1.58s
# 17:	learn: 1225.2040708	total: 838ms	remaining: 1.53s
# 18:	learn: 1223.3409357	total: 885ms	remaining: 1.49s
# 19:	learn: 1218.4223186	total: 932ms	remaining: 1.44s
# 20:	learn: 1213.3690244	total: 978ms	remaining: 1.4s
# 21:	learn: 1208.1009656	total: 1.02s	remaining: 1.35s
# 22:	learn: 1205.0800772	total: 1.07s	remaining: 1.3s
# 23:	learn: 1201.5471045	total: 1.12s	remaining: 1.26s
# 24:	learn: 1197.8432879	total: 1.17s	remaining: 1.21s
# 25:	learn: 1194.6919759	total: 1.21s	remaining: 1.17s
# 26:	learn: 1191.0741709	total: 1.26s	remaining: 1.12s
# 27:	learn: 1187.5963828	total: 1.31s	remaining: 1.08s
# 28:	learn: 1185.4421855	total: 1.36s	remaining: 1.03s
# 29:	learn: 1180.5999275	total: 1.41s	remaining: 984ms
# 30:	learn: 1178.0002276	total: 1.45s	remaining: 935ms
# 31:	learn: 1175.5285211	total: 1.5s	remaining: 889ms
# 32:	learn: 1173.4831860	total: 1.54s	remaining: 842ms
# 33:	learn: 1170.1785066	total: 1.59s	remaining: 796ms
# 34:	learn: 1168.1378821	total: 1.64s	remaining: 750ms
# 35:	learn: 1166.3006708	total: 1.68s	remaining: 701ms
# 36:	learn: 1164.4202737	total: 1.73s	remaining: 653ms
# 37:	learn: 1162.5592725	total: 1.78s	remaining: 608ms
# 38:	learn: 1161.2260605	total: 1.82s	remaining: 561ms
# 39:	learn: 1159.8684559	total: 1.86s	remaining: 513ms
# 40:	learn: 1158.1791278	total: 1.91s	remaining: 466ms
# 41:	learn: 1155.9229657	total: 1.96s	remaining: 420ms
# 42:	learn: 1154.8495506	total: 2s	remaining: 373ms
# 43:	learn: 1152.4720990	total: 2.05s	remaining: 326ms
# 44:	learn: 1150.0944071	total: 2.09s	remaining: 279ms
# 45:	learn: 1148.2820309	total: 2.14s	remaining: 232ms
# 46:	learn: 1145.5490873	total: 2.18s	remaining: 186ms
# 47:	learn: 1142.7695016	total: 2.23s	remaining: 139ms
# 48:	learn: 1140.5425185	total: 2.28s	remaining: 93ms
# 49:	learn: 1138.8357112	total: 2.32s	remaining: 46.5ms
# 50:	learn: 1137.1434293	total: 2.37s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2406.4211772	total: 6.74ms	remaining: 505ms
# 1:	learn: 2217.2267645	total: 12.6ms	remaining: 468ms
# 2:	learn: 2085.8440761	total: 18.6ms	remaining: 453ms
# 3:	learn: 1997.3952233	total: 24.5ms	remaining: 441ms
# 4:	learn: 1938.0498667	total: 30.6ms	remaining: 434ms
# 5:	learn: 1883.4384461	total: 37.1ms	remaining: 433ms
# 6:	learn: 1849.2587724	total: 43.4ms	remaining: 428ms
# 7:	learn: 1820.8434109	total: 50.5ms	remaining: 429ms
# 8:	learn: 1794.0602806	total: 57.8ms	remaining: 430ms
# 9:	learn: 1772.7863433	total: 64.5ms	remaining: 426ms
# 10:	learn: 1752.5147970	total: 71.9ms	remaining: 425ms
# 11:	learn: 1733.8716098	total: 78.8ms	remaining: 420ms
# 12:	learn: 1715.7296139	total: 85.7ms	remaining: 415ms
# 13:	learn: 1702.3783414	total: 92.3ms	remaining: 409ms
# 14:	learn: 1690.8715367	total: 99ms	remaining: 403ms
# 15:	learn: 1680.8837492	total: 106ms	remaining: 397ms
# 16:	learn: 1672.6476994	total: 113ms	remaining: 393ms
# 17:	learn: 1664.0680797	total: 122ms	remaining: 392ms
# 18:	learn: 1656.4018572	total: 128ms	remaining: 385ms
# 19:	learn: 1648.5014491	total: 135ms	remaining: 378ms
# 20:	learn: 1640.8418544	total: 143ms	remaining: 373ms
# 21:	learn: 1634.5721370	total: 150ms	remaining: 367ms
# 22:	learn: 1627.9276207	total: 157ms	remaining: 362ms
# 23:	learn: 1621.2667428	total: 164ms	remaining: 356ms
# 24:	learn: 1614.5775579	total: 171ms	remaining: 349ms
# 25:	learn: 1608.1598336	total: 178ms	remaining: 342ms
# 26:	learn: 1602.1699434	total: 185ms	remaining: 336ms
# 27:	learn: 1596.8080985	total: 192ms	remaining: 329ms
# 28:	learn: 1592.6989582	total: 199ms	remaining: 322ms
# 29:	learn: 1589.0137758	total: 206ms	remaining: 315ms
# 30:	learn: 1585.1381295	total: 213ms	remaining: 309ms
# 31:	learn: 1581.5594030	total: 219ms	remaining: 302ms
# 32:	learn: 1578.3836900	total: 226ms	remaining: 295ms
# 33:	learn: 1575.1620215	total: 234ms	remaining: 289ms
# 34:	learn: 1571.9506771	total: 241ms	remaining: 282ms
# 35:	learn: 1568.9659919	total: 248ms	remaining: 276ms
# 36:	learn: 1565.9293408	total: 255ms	remaining: 269ms
# 37:	learn: 1562.9971077	total: 263ms	remaining: 263ms
# 38:	learn: 1560.2785103	total: 269ms	remaining: 256ms
# 39:	learn: 1557.3886897	total: 276ms	remaining: 249ms
# 40:	learn: 1554.8247207	total: 283ms	remaining: 241ms
# 41:	learn: 1552.2108680	total: 289ms	remaining: 234ms
# 42:	learn: 1549.3831436	total: 296ms	remaining: 227ms
# 43:	learn: 1547.1451838	total: 303ms	remaining: 221ms
# 44:	learn: 1545.0411475	total: 311ms	remaining: 214ms
# 45:	learn: 1543.0603033	total: 318ms	remaining: 207ms
# 46:	learn: 1541.1280032	total: 324ms	remaining: 200ms
# 47:	learn: 1539.2095697	total: 331ms	remaining: 193ms
# 48:	learn: 1537.4185356	total: 338ms	remaining: 186ms
# 49:	learn: 1535.7133770	total: 346ms	remaining: 180ms
# 50:	learn: 1533.9857888	total: 354ms	remaining: 173ms
# 51:	learn: 1532.2778712	total: 361ms	remaining: 167ms
# 52:	learn: 1530.5605948	total: 368ms	remaining: 160ms
# 53:	learn: 1528.9146080	total: 375ms	remaining: 153ms
# 54:	learn: 1527.3085145	total: 381ms	remaining: 146ms
# 55:	learn: 1525.7416037	total: 388ms	remaining: 139ms
# 56:	learn: 1524.1766941	total: 396ms	remaining: 132ms
# 57:	learn: 1522.7706285	total: 403ms	remaining: 125ms
# 58:	learn: 1520.6449129	total: 411ms	remaining: 118ms
# 59:	learn: 1519.3207580	total: 417ms	remaining: 111ms
# 60:	learn: 1517.9889556	total: 424ms	remaining: 104ms
# 61:	learn: 1516.3458918	total: 430ms	remaining: 97.1ms
# 62:	learn: 1515.0124472	total: 437ms	remaining: 90.1ms
# 63:	learn: 1513.6031242	total: 443ms	remaining: 83.1ms
# 64:	learn: 1512.2971330	total: 450ms	remaining: 76.2ms
# 65:	learn: 1511.0474931	total: 457ms	remaining: 69.2ms
# 66:	learn: 1509.8399473	total: 463ms	remaining: 62.2ms
# 67:	learn: 1508.6957342	total: 469ms	remaining: 55.2ms
# 68:	learn: 1507.5698514	total: 476ms	remaining: 48.3ms
# 69:	learn: 1506.5378036	total: 482ms	remaining: 41.3ms
# 70:	learn: 1505.3661011	total: 489ms	remaining: 34.5ms
# 71:	learn: 1504.3685950	total: 496ms	remaining: 27.5ms
# 72:	learn: 1503.3853762	total: 503ms	remaining: 20.7ms
# 73:	learn: 1502.0925665	total: 509ms	remaining: 13.8ms
# 74:	learn: 1501.1564649	total: 516ms	remaining: 6.87ms
# 75:	learn: 1500.2539709	total: 522ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2130.0072082	total: 12.5ms	remaining: 941ms
# 1:	learn: 1793.5278272	total: 23.6ms	remaining: 872ms
# 2:	learn: 1621.5894609	total: 35.3ms	remaining: 860ms
# 3:	learn: 1524.1163768	total: 48.1ms	remaining: 865ms
# 4:	learn: 1473.5523643	total: 60.4ms	remaining: 858ms
# 5:	learn: 1441.9152850	total: 72.6ms	remaining: 848ms
# 6:	learn: 1425.6852057	total: 84.6ms	remaining: 834ms
# 7:	learn: 1400.6361759	total: 97.9ms	remaining: 832ms
# 8:	learn: 1384.3662931	total: 111ms	remaining: 826ms
# 9:	learn: 1372.9725639	total: 124ms	remaining: 819ms
# 10:	learn: 1361.8885555	total: 137ms	remaining: 812ms
# 11:	learn: 1354.0831876	total: 152ms	remaining: 809ms
# 12:	learn: 1348.8680810	total: 165ms	remaining: 798ms
# 13:	learn: 1340.6743638	total: 178ms	remaining: 788ms
# 14:	learn: 1336.6554873	total: 191ms	remaining: 776ms
# 15:	learn: 1331.4751500	total: 205ms	remaining: 768ms
# 16:	learn: 1324.6551759	total: 219ms	remaining: 759ms
# 17:	learn: 1319.6440221	total: 232ms	remaining: 748ms
# 18:	learn: 1314.1558412	total: 246ms	remaining: 737ms
# 19:	learn: 1310.6278324	total: 260ms	remaining: 727ms
# 20:	learn: 1307.8614767	total: 274ms	remaining: 717ms
# 21:	learn: 1303.8014120	total: 289ms	remaining: 709ms
# 22:	learn: 1300.0992097	total: 304ms	remaining: 700ms
# 23:	learn: 1294.3632411	total: 317ms	remaining: 687ms
# 24:	learn: 1292.3750784	total: 332ms	remaining: 677ms
# 25:	learn: 1289.3646059	total: 346ms	remaining: 666ms
# 26:	learn: 1286.3501071	total: 360ms	remaining: 654ms
# 27:	learn: 1282.2615637	total: 376ms	remaining: 645ms
# 28:	learn: 1279.2623059	total: 390ms	remaining: 632ms
# 29:	learn: 1277.0224722	total: 403ms	remaining: 618ms
# 30:	learn: 1274.7965468	total: 417ms	remaining: 605ms
# 31:	learn: 1271.6080797	total: 431ms	remaining: 592ms
# 32:	learn: 1268.6940737	total: 446ms	remaining: 581ms
# 33:	learn: 1266.2131057	total: 461ms	remaining: 569ms
# 34:	learn: 1263.3763725	total: 476ms	remaining: 558ms
# 35:	learn: 1261.4335802	total: 491ms	remaining: 546ms
# 36:	learn: 1258.8367404	total: 506ms	remaining: 533ms
# 37:	learn: 1256.5327484	total: 520ms	remaining: 520ms
# 38:	learn: 1254.7065348	total: 534ms	remaining: 507ms
# 39:	learn: 1253.3726375	total: 549ms	remaining: 494ms
# 40:	learn: 1251.0831334	total: 563ms	remaining: 481ms
# 41:	learn: 1248.9929017	total: 579ms	remaining: 468ms
# 42:	learn: 1247.0725458	total: 593ms	remaining: 455ms
# 43:	learn: 1245.8116388	total: 606ms	remaining: 441ms
# 44:	learn: 1244.4398730	total: 619ms	remaining: 427ms
# 45:	learn: 1241.5859517	total: 634ms	remaining: 414ms
# 46:	learn: 1239.4527432	total: 649ms	remaining: 400ms
# 47:	learn: 1237.5775657	total: 664ms	remaining: 387ms
# 48:	learn: 1236.0676801	total: 678ms	remaining: 373ms
# 49:	learn: 1234.0367101	total: 691ms	remaining: 359ms
# 50:	learn: 1233.6934615	total: 704ms	remaining: 345ms
# 51:	learn: 1232.0473446	total: 719ms	remaining: 332ms
# 52:	learn: 1231.3423392	total: 734ms	remaining: 318ms
# 53:	learn: 1229.5985850	total: 748ms	remaining: 305ms
# 54:	learn: 1228.5122071	total: 762ms	remaining: 291ms
# 55:	learn: 1227.4827054	total: 777ms	remaining: 277ms
# 56:	learn: 1226.4499667	total: 793ms	remaining: 264ms
# 57:	learn: 1224.6409403	total: 808ms	remaining: 251ms
# 58:	learn: 1223.2687551	total: 822ms	remaining: 237ms
# 59:	learn: 1221.5799732	total: 836ms	remaining: 223ms
# 60:	learn: 1220.7773806	total: 849ms	remaining: 209ms
# 61:	learn: 1219.6591417	total: 864ms	remaining: 195ms
# 62:	learn: 1218.2090475	total: 879ms	remaining: 181ms
# 63:	learn: 1217.3228588	total: 893ms	remaining: 167ms
# 64:	learn: 1216.4351205	total: 907ms	remaining: 154ms
# 65:	learn: 1214.7026651	total: 922ms	remaining: 140ms
# 66:	learn: 1213.2591477	total: 938ms	remaining: 126ms
# 67:	learn: 1211.9276495	total: 953ms	remaining: 112ms
# 68:	learn: 1210.8814138	total: 968ms	remaining: 98.2ms
# 69:	learn: 1209.9790786	total: 982ms	remaining: 84.2ms
# 70:	learn: 1208.7741709	total: 999ms	remaining: 70.3ms
# 71:	learn: 1207.8926428	total: 1.01s	remaining: 56.3ms
# 72:	learn: 1206.7177024	total: 1.03s	remaining: 42.2ms
# 73:	learn: 1205.4588075	total: 1.04s	remaining: 28.2ms
# 74:	learn: 1204.5804262	total: 1.05s	remaining: 14.1ms
# 75:	learn: 1203.5583555	total: 1.07s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 2029.4776431	total: 43.8ms	remaining: 3.29s
# 1:	learn: 1631.6784275	total: 85ms	remaining: 3.15s
# 2:	learn: 1472.5348848	total: 130ms	remaining: 3.15s
# 3:	learn: 1395.3600845	total: 175ms	remaining: 3.14s
# 4:	learn: 1361.6563124	total: 219ms	remaining: 3.1s
# 5:	learn: 1328.3983622	total: 263ms	remaining: 3.06s
# 6:	learn: 1313.6914512	total: 307ms	remaining: 3.02s
# 7:	learn: 1297.3681380	total: 351ms	remaining: 2.98s
# 8:	learn: 1288.2972502	total: 397ms	remaining: 2.96s
# 9:	learn: 1279.3144794	total: 440ms	remaining: 2.9s
# 10:	learn: 1265.5631479	total: 485ms	remaining: 2.87s
# 11:	learn: 1253.3057646	total: 532ms	remaining: 2.84s
# 12:	learn: 1248.2299516	total: 579ms	remaining: 2.81s
# 13:	learn: 1243.5001143	total: 629ms	remaining: 2.78s
# 14:	learn: 1238.8202857	total: 675ms	remaining: 2.74s
# 15:	learn: 1233.3917725	total: 721ms	remaining: 2.7s
# 16:	learn: 1228.8472896	total: 767ms	remaining: 2.66s
# 17:	learn: 1225.2040708	total: 815ms	remaining: 2.62s
# 18:	learn: 1223.3409357	total: 859ms	remaining: 2.58s
# 19:	learn: 1218.4223186	total: 908ms	remaining: 2.54s
# 20:	learn: 1213.3690244	total: 955ms	remaining: 2.5s
# 21:	learn: 1208.1009656	total: 1s	remaining: 2.46s
# 22:	learn: 1205.0800772	total: 1.04s	remaining: 2.41s
# 23:	learn: 1201.5471045	total: 1.09s	remaining: 2.37s
# 24:	learn: 1197.8432879	total: 1.14s	remaining: 2.33s
# 25:	learn: 1194.6919759	total: 1.19s	remaining: 2.29s
# 26:	learn: 1191.0741709	total: 1.24s	remaining: 2.24s
# 27:	learn: 1187.5963828	total: 1.28s	remaining: 2.19s
# 28:	learn: 1185.4421855	total: 1.33s	remaining: 2.15s
# 29:	learn: 1180.5999275	total: 1.38s	remaining: 2.11s
# 30:	learn: 1178.0002276	total: 1.42s	remaining: 2.06s
# 31:	learn: 1175.5285211	total: 1.47s	remaining: 2.02s
# 32:	learn: 1173.4831860	total: 1.51s	remaining: 1.97s
# 33:	learn: 1170.1785066	total: 1.56s	remaining: 1.93s
# 34:	learn: 1168.1378821	total: 1.61s	remaining: 1.88s
# 35:	learn: 1166.3006708	total: 1.65s	remaining: 1.84s
# 36:	learn: 1164.4202737	total: 1.7s	remaining: 1.79s
# 37:	learn: 1162.5592725	total: 1.74s	remaining: 1.74s
# 38:	learn: 1161.2260605	total: 1.79s	remaining: 1.7s
# 39:	learn: 1159.8684559	total: 1.84s	remaining: 1.65s
# 40:	learn: 1158.1791278	total: 1.88s	remaining: 1.6s
# 41:	learn: 1155.9229657	total: 1.92s	remaining: 1.56s
# 42:	learn: 1154.8495506	total: 1.97s	remaining: 1.51s
# 43:	learn: 1152.4720990	total: 2.01s	remaining: 1.46s
# 44:	learn: 1150.0944071	total: 2.06s	remaining: 1.42s
# 45:	learn: 1148.2820309	total: 2.1s	remaining: 1.37s
# 46:	learn: 1145.5490873	total: 2.15s	remaining: 1.32s
# 47:	learn: 1142.7695016	total: 2.19s	remaining: 1.28s
# 48:	learn: 1140.5425185	total: 2.23s	remaining: 1.23s
# 49:	learn: 1138.8357112	total: 2.28s	remaining: 1.19s
# 50:	learn: 1137.1434293	total: 2.33s	remaining: 1.14s
# 51:	learn: 1135.6346144	total: 2.37s	remaining: 1.09s
# 52:	learn: 1134.3293687	total: 2.42s	remaining: 1.05s
# 53:	learn: 1132.2400563	total: 2.47s	remaining: 1s
# 54:	learn: 1131.3154993	total: 2.51s	remaining: 960ms
# 55:	learn: 1130.1923887	total: 2.57s	remaining: 916ms
# 56:	learn: 1128.6908063	total: 2.62s	remaining: 872ms
# 57:	learn: 1127.2710855	total: 2.66s	remaining: 827ms
# 58:	learn: 1125.8388632	total: 2.71s	remaining: 782ms
# 59:	learn: 1124.4710033	total: 2.76s	remaining: 737ms
# 60:	learn: 1123.4463005	total: 2.81s	remaining: 692ms
# 61:	learn: 1122.3986306	total: 2.87s	remaining: 648ms
# 62:	learn: 1120.7415468	total: 2.92s	remaining: 603ms
# 63:	learn: 1118.9565543	total: 2.98s	remaining: 559ms
# 64:	learn: 1118.2470647	total: 3.03s	remaining: 512ms
# 65:	learn: 1116.9877419	total: 3.08s	remaining: 466ms
# 66:	learn: 1114.8574139	total: 3.13s	remaining: 420ms
# 67:	learn: 1113.0354930	total: 3.18s	remaining: 374ms
# 68:	learn: 1111.4233745	total: 3.23s	remaining: 328ms
# 69:	learn: 1110.3551134	total: 3.27s	remaining: 281ms
# 70:	learn: 1109.5775102	total: 3.32s	remaining: 234ms
# 71:	learn: 1108.4828529	total: 3.38s	remaining: 188ms
# 72:	learn: 1107.2521677	total: 3.43s	remaining: 141ms
# 73:	learn: 1106.6625678	total: 3.48s	remaining: 94.2ms
# 74:	learn: 1105.6291560	total: 3.54s	remaining: 47.1ms
# 75:	learn: 1104.1936928	total: 3.58s	remaining: 0us
# Best training time: 23.21875
# Best test time: 0.546875
# Best training score: 1104.1936927950594
# Best test score: 1185.5537619202262
# Best model & hyperparameters:

# %%
cbr_best_model.get_params()
# Out:
# {'loss_function': 'RMSE',
#  'max_depth': 11,
#  'n_estimators': 76,
#  'random_state': 12345}

# %% [markdown]
# ## Model performance review

# %%
performance_df = pd.DataFrame.from_dict(data=performance_dict, orient='index', columns=performance_columns)
performance_df
# Out:
#        Training time  Test time  Training score   Test score
# lr         34.031250   0.156250     1758.990891  1742.233666
# dtr         3.671875   0.125000     1159.816890  1356.930726
# rfr       152.343750   0.593750     1261.817628  1332.558566
# xgbr      580.593750   2.078125      934.158739  1160.486880
# lgbmr       8.625000   1.500000     1232.458374  1245.838632
# cbr        23.218750   0.546875     1104.193693  1185.553762

# %% [markdown]
# ### By prediction quality

# %%
performance_df.sort_values(by='Test score', ascending=True)
# Out:
#        Training time  Test time  Training score   Test score
# xgbr      580.593750   2.078125      934.158739  1160.486880
# cbr        23.218750   0.546875     1104.193693  1185.553762
# lgbmr       8.625000   1.500000     1232.458374  1245.838632
# rfr       152.343750   0.593750     1261.817628  1332.558566
# dtr         3.671875   0.125000     1159.816890  1356.930726
# lr         34.031250   0.156250     1758.990891  1742.233666

# %% [markdown]
# ### By prediction speed

# %%
performance_df.sort_values(by='Test time', ascending=True)
# Out:
#        Training time  Test time  Training score   Test score
# dtr         3.671875   0.125000     1159.816890  1356.930726
# lr         34.031250   0.156250     1758.990891  1742.233666
# cbr        23.218750   0.546875     1104.193693  1185.553762
# rfr       152.343750   0.593750     1261.817628  1332.558566
# lgbmr       8.625000   1.500000     1232.458374  1245.838632
# xgbr      580.593750   2.078125      934.158739  1160.486880

# %% [markdown]
# ### By training speed

# %%
performance_df.sort_values(by='Training time', ascending=True)
# Out:
#        Training time  Test time  Training score   Test score
# dtr         3.671875   0.125000     1159.816890  1356.930726
# lgbmr       8.625000   1.500000     1232.458374  1245.838632
# cbr        23.218750   0.546875     1104.193693  1185.553762
# lr         34.031250   0.156250     1758.990891  1742.233666
# rfr       152.343750   0.593750     1261.817628  1332.558566
# xgbr      580.593750   2.078125      934.158739  1160.486880

# %% [markdown]
# ### Summary
#
# Findings & insights:
# - All models did better than linear regression at predicting targets, as indicated by the lower RMSE scores.
# - All ensemble models (random forest regressor and every gradient-boosting models) hit peak performance at the same hyperparameters:
#     - `n_estimators = 76`
#     - `max_depth = 11`
# - Gradient boosting models made better predictions than the classic gradient descent models provided by sklearn. In ascending order of RMSE scores,
#     - XGBoost regressor (\~1160) did the best job at predicting target values, followed by
#     - CatBoost (\~1185) and
#     - LightGBM (\~1245) regressors.
# - However, gradient boosting models generally suffered from lower speed.
#     - CatBoost regressor, the 3rd fastest model in terms of prediction speed, was the only model with prediction speed of less than 1 second (\~0.5 seconds).
#     - LightGBM (1.5 seconds) and XGBoost (\~2.07 seconds) regressors were the slowest predictors.
#     - As a comparison, the fastest model (decision tree regressor) took \~0.125 seconds to predict the target values.
# - By training speed,
#     - LightGBM regressor (\~8.625 seconds) was the 2nd fastest model, followed by
#     - CatBoost regressor (\~23.21 seconds).
#     - XGBoost regressor was, again, the slowest model at \~580.59 seconds of fitting time.
#     - In comparison, the fastest model (again, decision tree regressor) took \~3.67 seconds to train.

# %% [markdown]
# # Conclusion
#
# We were given a set of 354,369 rows across 16 columns to train and test the models with.
#
# In preprocessing, we did the following:
# - removed 262 duplicate rows,
# - filled 30,657 missing `VehicleType`s with data from available models,
# - filled every other missing value with `unknown` placeholder category ,
# - removed rows with registration year before 1900 and after April 2016,
# - removed rows with outlier values in `Power` and `Price`,
# - dropped features that would not contribute to machine learning,
# - encoded non-ordinal categorical variables with one-hot encoding,
# - separated the features from the target.
#
# Data preprocessing resulted in a dataset of 236,305 rows (removing 118,064 rows, approximately 33% of the original dataset size) and 308 columns.
#
# Next, we trained the following models and tuned their hyperparameters where permitted:
# - linear regression (which served as the sanity check for other models due to its low configurability and simple algorithm),
# - decision tree regressor,
# - random forest regressor,
# - three implementations of gradient-boosting algorithms:
# 	- XGBoost regressor,
# 	- LightGBM regressor,
# 	- CatBoost regressor.
#
# The decision tree hit peak performance at `max_depth=14`. Meanwhile, all of the ensemble models reached best scores at `max_depth=11` and `n_estimators=76`.
#
# When reviewing the performance data of all models, we found out that gradient-boosting models achieved superior prediction quality, as indicated by their relatively low RMSE scores. However, this comes at the cost of being slower than models with simpler algorithms.
#
# Based on Rusty Bargain's criteria of prediction quality, prediction speed, and training speed, the best algorithm for their app would be an instance of **CatBoost regressor**, trained with our training set and the following hyperparameters:
#
# - `loss_function = RMSE`,
# - `max_depth = 11`,
# - `n_estimators = 76`,
# - `random_state = 12345`
